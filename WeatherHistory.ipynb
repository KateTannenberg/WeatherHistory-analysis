# %% [markdown]
# ## Введение
# В данной работе представлен анализ данных о погодных условиях, использованные данные взяты с сайта [kaggle](https://www.kaggle.com/datasets/muthuj7/weather-dataset). Целью является понимание и интерпретация метеорологических данных с помощью различных визуализаций. Это позволит нам увидеть скрытые закономерности и тренды, которые могут быть неочевидны при простом просмотре сырых данных.

# %% [markdown]
# ### Импорт библиотек

# %%
# import classes for Data Analysis
import numpy  as np
import pandas as pd
from scipy import stats

# import classes for data visulation
import matplotlib.pyplot    as plt
import seaborn              as sns
import plotly.express       as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
import plotly.io as pio
import panel as pn

import holoviews as hv
from holoviews import opts
hv.extension('bokeh')
from holoviews.streams import RangeXY
import hvplot.pandas
import panel as pn

import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# ### Импорт датасета

# %%
#importing the dataset
df = pd.read_csv("weatherHistory.csv")
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# 1             9.355556                  7.227778      0.86            14.2646
# 2             9.377778                  9.377778      0.89             3.9284
# 3             8.288889                  5.944444      0.83            14.1036
# 4             8.755556                  6.977778      0.83            11.0446
# ...                ...                       ...       ...                ...
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                       251.0          15.8263         0.0
# 1                       259.0          15.8263         0.0
# 2                       204.0          14.9569         0.0
# 3                       269.0          15.8263         0.0
# 4                       259.0          15.8263         0.0
# ...                       ...              ...         ...
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 0                   1015.13       Partly cloudy throughout the day.
# 1                   1015.63       Partly cloudy throughout the day.
# 2                   1015.94       Partly cloudy throughout the day.
# 3                   1016.41       Partly cloudy throughout the day.
# 4                   1016.51       Partly cloudy throughout the day.
# ...                     ...                                     ...
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.
#
# [96453 rows x 12 columns]

# %% [markdown]
# ### Проверка на NULL значения
# Проверим на наличие NULL значений и если такие имеются, заполним ячейки значениями стоящими выше по столбцу.

# %%
#checking the null count
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
#replace the missing values by front fill
df['Precip Type'].ffill(inplace = True)

# %%
#checking the null count
df.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# ### Конечная подготовка данных

# %% [markdown]
# #### Удалим ненужный столбец "Daily Summary" так как его уже представляет столбец "Summary"

# %%
#deleting the "Daily Summary", we don't need it because we have the "Summary" function
df.drop(["Daily Summary"], axis=1, inplace=True)

# %%
#check
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)'],
#       dtype='object')

# %% [markdown]
# #### Меняем формат "Formatted Date" с String на Datetime и сортируем по этому столбцу

# %%
#changing Formatted Date from String to Datetime
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'],utc=True)
df.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                  float64
# Visibility (km)                         float64
# Loud Cover                              float64
# Pressure (millibars)                    float64
# dtype: object

# %%
#sort dataframe by date
df = df.sort_values(by='Formatted Date')

# %% [markdown]
# #### Создание квартального, меячного, недельного датасета и датасета по дням

# %%
#creating a quarterly monthly and daily dataframe
data = df.copy()

#indexing values in precip type and summary
precip_type = {'rain': 1, 'snow': 0}
data['Precip Type Index'] = data['Precip Type'].map(precip_type)

unique_values_summary = df['Summary'].unique()
summary = dict(zip(unique_values_summary, list(range(27))))
data['Summary index'] = data['Summary'].map(summary)

#adding year values
data['Year']=data['Formatted Date'].dt.year
data
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 2880  2005-12-31 23:00:00+00:00  Partly Cloudy        rain         0.577778
# 2881  2006-01-01 00:00:00+00:00  Mostly Cloudy        rain         1.161111
# 2882  2006-01-01 01:00:00+00:00  Mostly Cloudy        rain         1.666667
# 2883  2006-01-01 02:00:00+00:00       Overcast        rain         1.711111
# 2884  2006-01-01 03:00:00+00:00  Mostly Cloudy        rain         1.183333
# ...                         ...            ...         ...              ...
# 89728 2016-12-31 18:00:00+00:00  Mostly Cloudy        rain         0.488889
# 89729 2016-12-31 19:00:00+00:00  Mostly Cloudy        rain         0.072222
# 89730 2016-12-31 20:00:00+00:00  Mostly Cloudy        snow        -0.233333
# 89731 2016-12-31 21:00:00+00:00  Mostly Cloudy        snow        -0.472222
# 89732 2016-12-31 22:00:00+00:00  Mostly Cloudy        snow        -0.677778
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 2880                  -4.050000      0.89            17.1143
# 2881                  -3.238889      0.85            16.6152
# 2882                  -3.155556      0.82            20.2538
# 2883                  -2.194444      0.82            14.4900
# 2884                  -2.744444      0.86            13.9426
# ...                         ...       ...                ...
# 89728                 -2.644444      0.86             9.7566
# 89729                 -3.050000      0.88             9.4185
# 89730                 -3.377778      0.89             9.2736
# 89731                 -3.644444      0.91             9.2414
# 89732                 -3.888889      0.92             9.2253
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 2880                    140.0           9.9820         0.0
# 2881                    139.0           9.9015         0.0
# 2882                    140.0           9.9015         0.0
# 2883                    140.0           9.9015         0.0
# 2884                    134.0           9.9015         0.0
# ...                       ...              ...         ...
# 89728                   167.0           8.0178         0.0
# 89729                   169.0           7.2450         0.0
# 89730                   175.0           9.5795         0.0
# 89731                   182.0           8.4042         0.0
# 89732                   189.0           8.8711         0.0
#
#        Pressure (millibars)  Precip Type Index  Summary index  Year
# 2880                1016.66                  1              0  2005
# 2881                1016.15                  1              1  2006
# 2882                1015.87                  1              1  2006
# 2883                1015.56                  1              2  2006
# 2884                1014.98                  1              1  2006
# ...                     ...                ...            ...   ...
# 89728               1020.03                  1              1  2016
# 89729               1020.27                  1              1  2016
# 89730               1020.50                  0              1  2016
# 89731               1020.65                  0              1  2016
# 89732               1020.72                  0              1  2016
#
# [96453 rows x 14 columns]

# %%
#creating a dictionary of aggregating functions
agg_funcs = {'Summary index': lambda x: stats.mode(x)[0],
             'Precip Type Index': lambda x: stats.mode(x)[0],
             'Temperature (C)': 'mean',
             'Apparent Temperature (C)': 'mean',
             'Humidity': 'mean',
             'Wind Speed (km/h)': 'mean',
             'Wind Bearing (degrees)': 'mean',
             'Visibility (km)': 'mean',
             'Loud Cover': 'mean',
             'Pressure (millibars)': 'mean'}

df_resample = data.set_index('Formatted Date')
df_resample_date = df_resample.resample('D').apply(agg_funcs)
df_resample_week = df_resample.resample('W').apply(agg_funcs)
df_resample_month = df_resample.resample('M').apply(agg_funcs)
df_resample_quarter = df_resample.resample('Q').apply(agg_funcs)

df_resample_week = df_resample_week.reset_index().copy()
df_resample_date = df_resample_date.reset_index().copy()
df_resample_week
# Out:
#                Formatted Date  Summary index  Precip Type Index  \
# 0   2006-01-01 00:00:00+00:00              1                  1
# 1   2006-01-08 00:00:00+00:00              2                  1
# 2   2006-01-15 00:00:00+00:00              1                  0
# 3   2006-01-22 00:00:00+00:00              2                  0
# 4   2006-01-29 00:00:00+00:00              0                  0
# ..                        ...            ...                ...
# 570 2016-12-04 00:00:00+00:00              1                  1
# 571 2016-12-11 00:00:00+00:00              1                  1
# 572 2016-12-18 00:00:00+00:00              1                  1
# 573 2016-12-25 00:00:00+00:00              1                  1
# 574 2017-01-01 00:00:00+00:00              1                  0
#
#      Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0           3.935111                 -0.329556  0.820000          21.064596
# 1           2.107903                 -0.040972  0.907500           9.201725
# 2          -1.226819                 -2.651521  0.866429           5.628675
# 3          -1.579563                 -4.892890  0.847024          11.652758
# 4          -7.093221                -10.057606  0.720119           7.811279
# ..               ...                       ...       ...                ...
# 570         2.842063                 -0.093089  0.877560          11.040096
# 571         1.961442                 -1.158168  0.885714          11.060508
# 572         1.216634                 -2.061144  0.890476          11.090313
# 573         0.618056                 -2.759524  0.891488          11.000613
# 574         0.206915                 -3.227389  0.889231          10.908257
#
#      Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)
# 0                142.640000        11.293828         0.0           1012.172000
# 1                153.922619         6.898946         0.0           1005.507202
# 2                183.732143         5.745017         0.0           1022.832976
# 3                199.059524         9.245808         0.0           1022.191429
# 4                 92.386905         9.773371         0.0           1034.094167
# ..                      ...              ...         ...                   ...
# 570              170.898810         7.907400         0.0           1019.411964
# 571              175.446429         7.593258         0.0           1019.689702
# 572              177.547619         7.403412         0.0           1019.929643
# 573              182.452381         7.319367         0.0           1020.148036
# 574              185.853147         7.292512         0.0           1020.348252
#
# [575 rows x 11 columns]

# %%
precip_type = {
    0: 'snow',
    1: 'rain'
}
summary = dict(zip(list(range(27)), unique_values_summary))

def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Autumn'

df_resample_date['Summary'] = df_resample_date['Summary index'].map(summary)
df_resample_date['Precip Type'] = df_resample_date['Precip Type Index'].map(precip_type)
df_resample_date['Year'] = df_resample_date['Formatted Date'].dt.year
df_resample_date['Season'] = df_resample_date['Formatted Date'].dt.month.apply(get_season)


df_resample_week['Summary'] = df_resample_week['Summary index'].map(summary)
df_resample_week['Precip Type'] = df_resample_week['Precip Type Index'].map(precip_type)
df_resample_week['Year'] = df_resample_week['Formatted Date'].dt.year
df_resample_week['Week'] = df_resample_week['Formatted Date'].dt.strftime('%U').astype('int')
df_resample_week['Season'] = df_resample_week['Formatted Date'].dt.month.apply(get_season)

df_resample_month['Summary'] = df_resample_month['Summary index'].map(summary)
df_resample_month['Precip Type'] = df_resample_month['Precip Type Index'].map(precip_type)

df_resample_quarter['Summary'] = df_resample_quarter['Summary index'].map(summary)
df_resample_quarter['Precip Type'] = df_resample_quarter['Precip Type Index'].map(precip_type)

df_resample_date = df_resample_date[df_resample_date['Year'] >= 2006]
df_resample_week = df_resample_week[df_resample_week['Year'] >= 2006]
df_resample_date
# Out:
#                 Formatted Date  Summary index  Precip Type Index  \
# 1    2006-01-01 00:00:00+00:00              1                  1
# 2    2006-01-02 00:00:00+00:00              2                  1
# 3    2006-01-03 00:00:00+00:00              2                  1
# 4    2006-01-04 00:00:00+00:00              2                  1
# 5    2006-01-05 00:00:00+00:00              2                  1
# ...                        ...            ...                ...
# 4014 2016-12-27 00:00:00+00:00              1                  0
# 4015 2016-12-28 00:00:00+00:00              1                  0
# 4016 2016-12-29 00:00:00+00:00              1                  0
# 4017 2016-12-30 00:00:00+00:00              1                  0
# 4018 2016-12-31 00:00:00+00:00              1                  0
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1            4.075000                 -0.174537  0.817083          21.229192
# 2            5.263194                  1.808796  0.847083          17.824713
# 3            2.340509                  0.445370  0.897083           7.726658
# 4            2.251852                 -0.663194  0.906667          12.152817
# 5            2.703935                  0.445833  0.951250           8.991179
# ...               ...                       ...       ...                ...
# 4014         0.278009                 -3.160417  0.890000          10.979529
# 4015         0.222222                 -3.225926  0.890000          10.968125
# 4016         0.167824                 -3.265509  0.889583          10.876892
# 4017         0.117593                 -3.309259  0.889167          10.810479
# 4018         0.113527                 -3.320773  0.886522          10.836700
#
#       Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 1                 142.750000        11.348487         0.0
# 2                 164.583333         8.492079         0.0
# 3                 252.541667         9.223958         0.0
# 4                  35.000000         8.352546         0.0
# 5                 139.875000         4.308092         0.0
# ...                      ...              ...         ...
# 4014              185.875000         7.303362         0.0
# 4015              186.083333         7.304704         0.0
# 4016              186.041667         7.310071         0.0
# 4017              186.000000         7.316779         0.0
# 4018              185.782609         7.213500         0.0
#
#       Pressure (millibars)        Summary Precip Type  Year  Season
# 1              1011.985000  Mostly Cloudy        rain  2006  Winter
# 2              1010.384167       Overcast        rain  2006  Winter
# 3              1021.170833       Overcast        rain  2006  Winter
# 4               981.770833       Overcast        rain  2006  Winter
# 5               935.873750       Overcast        rain  2006  Winter
# ...                    ...            ...         ...   ...     ...
# 4014           1020.305833  Mostly Cloudy        snow  2016  Winter
# 4015           1020.335833  Mostly Cloudy        snow  2016  Winter
# 4016           1020.367083  Mostly Cloudy        snow  2016  Winter
# 4017           1020.396250  Mostly Cloudy        snow  2016  Winter
# 4018           1020.413043  Mostly Cloudy        snow  2016  Winter
#
# [4018 rows x 15 columns]

# %% [markdown]
# ### Распределение по температуре

# %%
#Distribution of temperature and apparent temperature
temperature = df_resample_date[['Year', 'Temperature (C)', 'Season']]\
.hvplot.kde(y = 'Temperature (C)',
             groupby = ['Year', 'Season'], 
             grid = True)
apparent_temperature = df_resample_week[['Year', 'Apparent Temperature (C)', 'Season']]\
.hvplot.kde(y = 'Apparent Temperature (C)',
             groupby = ['Year', 'Season'], 
             grid = True)
temperature*apparent_temperature
# Out:
# :DynamicMap   [Year,Season]
#    :Overlay
#       .Distribution.I  :Distribution   [Temperature (C)]   (Density)
#       .Distribution.II :Distribution   [Apparent Temperature (C)]   (Density)

# %%
Temperature_distribution = df_resample_date.groupby(['Year', 'Season']).apply(
    lambda x: x[['Temperature (C)', 'Apparent Temperature (C)']].round(0).mode().iloc[0]
)
Temperature_distribution
# Out:
# 0            Temperature (C)  Apparent Temperature (C)
# Year Season
# 2006 Autumn             18.0                      18.0
#      Spring             14.0                      14.0
#      Summer             19.0                      19.0
#      Winter             -1.0                      -2.0
# 2007 Autumn              7.0                       5.0
#      Spring             10.0                      10.0
#      Summer             23.0                      23.0
#      Winter              7.0                       0.0
# 2008 Autumn             14.0                      14.0
#      Spring              9.0                       8.0
#      Summer             22.0                      22.0
#      Winter              5.0                      -2.0
# 2009 Autumn             18.0                      18.0
#      Spring             14.0                      14.0
#      Summer             21.0                      21.0
#      Winter              4.0                       4.0
# 2010 Autumn             11.0                      11.0
#      Spring              9.0                      13.0
#      Summer             21.0                      21.0
#      Winter              0.0                      -4.0
# 2011 Autumn             18.0                      18.0
#      Spring             14.0                      13.0
#      Summer             19.0                      19.0
#      Winter              2.0                      -5.0
# 2012 Autumn             10.0                       7.0
#      Spring             12.0                      11.0
#      Summer             23.0                      22.0
#      Winter              4.0                       1.0
# 2013 Autumn             13.0                      13.0
#      Spring             19.0                      12.0
#      Summer             22.0                      22.0
#      Winter             -1.0                      -3.0
# 2014 Autumn             14.0                      14.0
#      Spring             11.0                      12.0
#      Summer             19.0                      19.0
#      Winter              6.0                       4.0
# 2015 Autumn             11.0                      13.0
#      Spring              7.0                      16.0
#      Summer             23.0                      23.0
#      Winter              1.0                      -1.0
# 2016 Autumn              7.0                       7.0
#      Spring             16.0                      16.0
#      Summer             22.0                      22.0
#      Winter              2.0                      -3.0

# %% [markdown]
# **Посмотрим на распределение температур для разных годов и сезонов**
# В данной таблице вы можете увидеть наиболее часто встречаемую температуру в разные года и сезоны. **Летом** температура в среднем с 2006го по 2016й равна от 19 до 24 градусов, то есть нельзя сказать что в какой-то из годов наблюдались аномалии по температуре летом. **Осень** в 2006, 2008, 2009 и 2011 году была теплая и наиболее частая температура была примерно 18 градусов, самые холодные осени были в 2016, 2012 и 2007 году со своими 5 и 7 градусами. **Весна** не отличается за все годы аномалиями, выделить можно самые теплые 2016 и 2015 год с 16ю градусами, и самый холодный 2008 год с 8-9ю градусами тепла, выделить можно 2015 год, где можно заметить сильный разброс с фактической и ощущаемой температурой, но если посмотреть на график, то можно понять что самой частой из фактических температур - это 7 и 16 градусов, для ощущаемой это 7 и 15 градусов, так что аномалии здесь нет. **Зима** самая теплая зима была в 2014 и 2009 году, холодные зимы выпала на 2011 год. В целом, сильных перепадов по температуре не замечается.

# %% [markdown]
# ### Распределение по скорости ветра

# %%
#Distribution of wind speed
wind_speed = df_resample_date[['Year', 'Wind Speed (km/h)', 'Season']]\
.hvplot.kde(y = 'Wind Speed (km/h)',
             groupby = ['Year', 'Season'], 
             grid = True)
wind_speed
# Out:
# :DynamicMap   [Year,Season]
#    :Distribution   [Wind Speed (km/h)]   (Density)

# %%
Wind_Speed_distribution = df_resample_date.groupby(['Year', 'Season']).apply(
    lambda x: x[['Wind Speed (km/h)']].round(0).mode().iloc[0]
)
Wind_Speed_distribution
# Out:
# 0            Wind Speed (km/h)
# Year Season
# 2006 Autumn               10.0
#      Spring               12.0
#      Summer                8.0
#      Winter                5.0
# 2007 Autumn                9.0
#      Spring                9.0
#      Summer               10.0
#      Winter                5.0
# 2008 Autumn                4.0
#      Spring               11.0
#      Summer                8.0
#      Winter               11.0
# 2009 Autumn                6.0
#      Spring                9.0
#      Summer                7.0
#      Winter                8.0
# 2010 Autumn                6.0
#      Spring               11.0
#      Summer                7.0
#      Winter               10.0
# 2011 Autumn                6.0
#      Spring                7.0
#      Summer                5.0
#      Winter                9.0
# 2012 Autumn                9.0
#      Spring                9.0
#      Summer                9.0
#      Winter                7.0
# 2013 Autumn                9.0
#      Spring               12.0
#      Summer                7.0
#      Winter                7.0
# 2014 Autumn                7.0
#      Spring                8.0
#      Summer                9.0
#      Winter               10.0
# 2015 Autumn                7.0
#      Spring                9.0
#      Summer                6.0
#      Winter                5.0
# 2016 Autumn               11.0
#      Spring               10.0
#      Summer                4.0
#      Winter               11.0

# %% [markdown]
# Зависимости скорости ветра от времени года не замечено

# %% [markdown]
# ### Зависимость влажности от температуры

# %%
#Dependence of humidity on temperature plot
humidity_vs_temperature = df_resample_date[['Season', 'Year', 'Temperature (C)', 'Humidity']]\
.hvplot.scatter(x ='Temperature (C)',
             y = 'Humidity', 
             groupby = 'Year',
             by = 'Season',grid = True)
humidity_vs_temperature
# Out:
# :DynamicMap   [Year]
#    :NdOverlay   [Season]
#       :Scatter   [Temperature (C)]   (Humidity)

# %% [markdown]
# Можно заметить зависимость: чем выше температура тем ниже влажность. Можно также заметить что при одинаковом разбросе температур влажность осенью выше чем влажность весной.

# %% [markdown]
# ### Зависимость видимости от скорости ветра

# %%
#Dependence of visibility on wind speed plot
visibility_vs_windspeed = df_resample_date[['Year', 'Season', 'Wind Speed (km/h)', 'Visibility (km)']]\
.hvplot.scatter(x ='Wind Speed (km/h)',
             y ='Visibility (km)', 
             by = 'Season',
             groupby = 'Year', 
             grid = True)
visibility_vs_windspeed
# Out:
# :DynamicMap   [Year]
#    :NdOverlay   [Season]
#       :Scatter   [Wind Speed (km/h)]   (Visibility (km))

# %% [markdown]
# Можно заметить что при любой скорости ветра весной и летом видимость будет на уровне 12ти или 15ти, для зимы и для осени видимость равномерно разбросана по полю, думаю это связано с тем что осенью и зимой на улице могут быть опавшие листья или снег, которые могут повлиять на значения видимости. Также можем заметить что при высокой скорости ветра значения видимости в любой сезон достаточно высокие, когда как при маленькой скорости ветра наблюдается больше значений, означающих плохую видимость.

# %% [markdown]
# ### Зависимость давления от температуры

# %%
#Dependence of pressure on temperature plot
pressure_vs_temperature = df_resample_date[['Year', 'Season', 'Pressure (millibars)', 'Temperature (C)']]\
.hvplot.scatter(x ='Temperature (C)',
             y ='Pressure (millibars)', 
             by = 'Season',
             groupby = 'Year', 
             grid = True)
pressure_vs_temperature
# Out:
# :DynamicMap   [Year]
#    :NdOverlay   [Season]
#       :Scatter   [Temperature (C)]   (Pressure (millibars))

# %% [markdown]
# Особой зависимости давления от температуры не наблюдается, она находится примерно на уровне 1000 мм рт ст., в 2013м наблюдалось достаточно много выбросов зимой (наблюдается падение давления), а в 2012 наблюдались выбросы летом.

# %% [markdown]
# ### Зависимость типа осадков от температурных условий

# %%
#Dependence of precip type on temperature plot
PrecipType_vs_Temperature = df_resample_date[['Year', 'Season', 'Temperature (C)', 'Precip Type']]\
.hvplot.box(y = 'Temperature (C)',  
            by = 'Precip Type',
            groupby = 'Year', 
            height = 600, 
            width = 400)
PrecipType_vs_Temperature
# Out:
# :DynamicMap   [Year]
#    :BoxWhisker   [Precip Type]   (Temperature (C))

# %%
df_quantile = df_resample_date.groupby(['Year', 'Precip Type'])['Temperature (C)'].agg([
    ('median','median'), 
    ('lower quantile', lambda x: x.quantile(0.25)), 
    ('apper quantile', lambda x: x.quantile(0.75))
]).reset_index()
df_quantile
# Out:
#     Year Precip Type     median  lower quantile  apper quantile
# 0   2006        rain  13.913657        8.229514       18.797917
# 1   2006        snow  -1.706944       -3.465741       -1.218750
# 2   2007        rain  12.215741        6.971296       20.062500
# 3   2007        snow  -3.491204       -4.242477       -2.247106
# 4   2008        rain  12.745718        7.318576       19.810012
# 5   2008        snow  -2.296528       -5.576562       -1.027662
# 6   2009        rain  15.002083        6.876852       20.565278
# 7   2009        snow  -3.191782       -5.956366       -0.998900
# 8   2010        rain  13.209491        8.758218       19.604572
# 9   2010        snow  -2.350694       -5.953241       -0.820139
# 10  2011        rain  15.779630        7.738542       20.722222
# 11  2011        snow  -1.701157       -3.506713       -0.577488
# 12  2012        rain  15.046991        7.675463       21.493287
# 13  2012        snow  -3.384722       -7.977778       -1.619213
# 14  2013        rain  14.184028        6.963600       19.461343
# 15  2013        snow  -1.157870       -2.128704       -0.565972
# 16  2014        rain  13.525116        7.334954       18.829803
# 17  2014        snow  -3.505093       -4.487500       -1.870602
# 18  2015        rain  12.850231        6.017824       19.873264
# 19  2015        snow  -0.783218       -2.093576        0.146817
# 20  2016        rain  12.176042        6.504167       20.095718
# 21  2016        snow  -2.690394       -4.325810       -0.169907

# %% [markdown]
# В таблице выше можно увидеть значения медианы, верхнего и нижнего квартиля в каждой группе с одинаковым годом и видом осадков. В целом, нельзя заметить выбросы в этих значениях. К примеру, медианы для дождя колеблются от 12ти до 16ти градусов, для снега от -3.5 до -0.5. В таких же диапазонах колеблются значения для нижнего и верхнего квартиля для дождя и снега.

# %% [markdown]
# ### Распределение сводки погоды по дням

# %%
#Weather distribution by day plot
df_resample_date_groupby = df_resample_date.groupby(['Summary','Year', 'Season'])['Formatted Date'].count().reset_index()
df_resample_date_groupby
summary_count = df_resample_date_groupby\
.hvplot.barh(x = 'Summary',
            y = 'Formatted Date', 
            by = 'Season',
            groupby = 'Year',
            grid = True, 
            height = 800,
            width = 600)
summary_count
# Out:
# :DynamicMap   [Year]
#    :Bars   [Summary,Season]   (Formatted Date)

# %%
df_summary_count = df_resample_date.groupby(['Year','Summary'])['Summary'].agg({
    ('Summary_count', 'count')
}).reset_index()
df_summary_count['Summary_percent'] = 100 * df_summary_count['Summary_count'] / \
df_summary_count.groupby(['Year'])['Summary_count'].transform('sum')
df_summary_count['rn'] = df_summary_count.sort_values('Summary_count', ascending=False).groupby(['Year']).cumcount()+1
df_summary_count.head(50)
# Out:
#     Year                   Summary  Summary_count  Summary_percent  rn
# 0   2006                     Clear             38        10.410959   4
# 1   2006                     Foggy             27         7.397260   5
# 2   2006             Mostly Cloudy             98        26.849315   2
# 3   2006                  Overcast             65        17.808219   3
# 4   2006             Partly Cloudy            137        37.534247   1
# 5   2007                     Clear             35         9.589041   4
# 6   2007                     Foggy             14         3.835616   5
# 7   2007             Mostly Cloudy             75        20.547945   2
# 8   2007                  Overcast             65        17.808219   3
# 9   2007             Partly Cloudy            175        47.945205   1
# 10  2007   Windy and Partly Cloudy              1         0.273973   6
# 11  2008  Breezy and Mostly Cloudy              1         0.273224   7
# 12  2008  Breezy and Partly Cloudy              1         0.273224   6
# 13  2008                     Clear             22         6.010929   4
# 14  2008                     Foggy             17         4.644809   5
# 15  2008             Mostly Cloudy            117        31.967213   2
# 16  2008                  Overcast             55        15.027322   3
# 17  2008             Partly Cloudy            153        41.803279   1
# 18  2009  Breezy and Mostly Cloudy              2         0.547945   6
# 19  2009       Breezy and Overcast              1         0.273973   7
# 20  2009                     Clear             17         4.657534   5
# 21  2009                     Foggy             32         8.767123   4
# 22  2009             Mostly Cloudy            112        30.684932   2
# 23  2009                  Overcast             53        14.520548   3
# 24  2009             Partly Cloudy            148        40.547945   1
# 25  2010       Breezy and Overcast              1         0.273973   6
# 26  2010                     Clear             14         3.835616   5
# 27  2010                     Foggy             29         7.945205   4
# 28  2010             Mostly Cloudy            113        30.958904   2
# 29  2010                  Overcast             67        18.356164   3
# 30  2010             Partly Cloudy            141        38.630137   1
# 31  2011       Breezy and Overcast              2         0.547945   6
# 32  2011                     Clear             30         8.219178   5
# 33  2011                     Foggy             32         8.767123   4
# 34  2011             Mostly Cloudy            104        28.493151   2
# 35  2011                  Overcast             51        13.972603   3
# 36  2011             Partly Cloudy            145        39.726027   1
# 37  2011   Windy and Partly Cloudy              1         0.273973   7
# 38  2012       Breezy and Overcast              2         0.546448   6
# 39  2012                     Clear             33         9.016393   4
# 40  2012                     Foggy             20         5.464481   5
# 41  2012             Mostly Cloudy             98        26.775956   2
# 42  2012                  Overcast             49        13.387978   3
# 43  2012             Partly Cloudy            164        44.808743   1
# 44  2013  Breezy and Mostly Cloudy              1         0.273973   6
# 45  2013       Breezy and Overcast              1         0.273973   7
# 46  2013                     Clear             16         4.383562   4
# 47  2013                     Foggy             16         4.383562   5
# 48  2013             Mostly Cloudy            126        34.520548   2
# 49  2013                  Overcast             63        17.260274   3

# %% [markdown]
# На графике выше можно увидеть распределение сводки погоды по количеству дней. Для удобства сделала таблицу чтобы посмотреть долю количества дней с определенной погодой. Можно заметить что для каждого года самое большое количество дней были пасмурными (в среднем 15%), преимущественно (в среднем 28% года) и частично облачными (в среднем 41% года), дальше по количеству дней идут обычно ясные дни, они составляют от 3.5 до 10.5% года.

# %% [markdown]
# ### Рассмотрение данных с точки зрения выбросов

# %% [markdown]
# #### Определим какие значения можно считать выбросом для давления, температуры и скорости ветра используя метод IQR

# %%
#defining of emissions using IQR

#Pressure
#calculation Q1, Q3 and IQR
Q1 = df_resample_date['Pressure (millibars)'].quantile(0.25)
Q3 = df_resample_date['Pressure (millibars)'].quantile(0.75)
IQR = Q3 - Q1

#defining emission limits
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#identification of emissions
df_resample_date['Pressure emission'] = np.where((df_resample_date['Pressure (millibars)'] 
                            < lower_bound) |(df_resample_date['Pressure (millibars)'] 
                            > upper_bound), 'anomaly', 'within normal limits')
#Temperature
#calculation Q1, Q3 and IQR
Q1 = df_resample_date['Temperature (C)'].quantile(0.25)
Q3 = df_resample_date['Temperature (C)'].quantile(0.75)
IQR = Q3 - Q1

#defining emission limits
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#identification of emissions
df_resample_date['Temperature emission'] = np.where((df_resample_date['Temperature (C)'] 
                            < lower_bound) |(df_resample_date['Temperature (C)'] 
                            > upper_bound), 'anomaly', 'within normal limits')

#Temperature
#calculation Q1, Q3 and IQR
Q1 = df_resample_date['Temperature (C)'].quantile(0.25)
Q3 = df_resample_date['Temperature (C)'].quantile(0.75)
IQR = Q3 - Q1

#defining emission limits
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#identification of emissions
df_resample_date['Temperature emission'] = np.where((df_resample_date['Temperature (C)'] 
                            < lower_bound) |(df_resample_date['Temperature (C)'] 
                            > upper_bound), 'anomaly', 'within normal limits')

#Wind Speed
#calculation Q1, Q3 and IQR
Q1 = df_resample_date['Wind Speed (km/h)'].quantile(0.25)
Q3 = df_resample_date['Wind Speed (km/h)'].quantile(0.75)
IQR = Q3 - Q1

#defining emission limits
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#identification of emissions
conditions = [
    (df_resample_date['Wind Speed (km/h)'] < lower_bound),
    (df_resample_date['Wind Speed (km/h)'] > upper_bound),
    (df_resample_date['Wind Speed (km/h)'] >= lower_bound) |\
    (df_resample_date['Wind Speed (km/h)'] <= upper_bound)]
choices = ['little', 'anomaly fast', 'within normal limits']
df_resample_date['Wind speed emission'] = np.select(conditions, choices)

#checking the connection between strong wind and anomaly pressure
df_resample_date['meaning'] = np.where((df_resample_date['Wind speed emission'] 
                            == 'anomaly fast') &(df_resample_date['Pressure emission'] 
                            == 'anomaly'), 'match', 'not match')

# %% [markdown]
# #### Распределение погодных сводок по аномальным и неаномальным значениям давления

# %%
#Summary by anomaly pressure plot
summary_by_anomaly = df_resample_date.groupby(['Summary', 'Year', 'Pressure emission'])['Formatted Date'].count().reset_index()
summary_count = summary_by_anomaly\
.hvplot.barh(x = 'Summary',
            y = 'Formatted Date', 
            by = 'Pressure emission',
            groupby = 'Year',
            grid = True, 
            height = 1000,
            width = 600)
summary_count
# Out:
# :DynamicMap   [Year]
#    :Bars   [Summary,Pressure emission]   (Formatted Date)

# %% [markdown]
# Рассмотрим зависимость сводки погоды от аномалий по давлению, сразу заметим что наибольшее количество аномалий было в 2006-м году, причем большинство из дней с аномальным давлением приходится на дни с преимущественной облачностью. В ясные и туманные дни тоже бывают аномалии по давлению, но таких дней в среднем меньшем. Понятно что в целом из-за того что дней с облачностью больше относительно других дней, то и больше вероятность выпадения дней с аномальным давлением на эти дни, также можно заметить что дни с аномальным давлением выпадают и на ясные дни,   поэтому из данных не было заметна зависимость между аномалиями по давлению и изменением погодных условий

# %% [markdown]
# #### Проверка наличия выбросов в температурных значениях

# %%
#Сhecking anomaly temperature values
summary_by_anomaly = df_resample_date.groupby(['Temperature emission'])['Formatted Date'].count().reset_index()
summary_by_anomaly
#summary_count = summary_by_anomaly\
#.hvplot.barh(x = 'Summary',
#            y = 'Formatted Date', 
#            by = 'Temperature emission',
#            groupby = 'Year',
#            grid = True, 
#            height = 800,
#            width = 600)
#summary_count
# Out:
#    Temperature emission  Formatted Date
# 0  within normal limits            4018

# %% [markdown]
# Аномальных температур не замечаем

# %% [markdown]
# #### Распределение погодных сводок по аномальным и неаномальным значениям скорости ветра

# %%
#Summary by anomaly wind speed plot
summary_by_anomaly = df_resample_date.groupby(['Summary', 'Wind speed emission','Year'])['Formatted Date'].count().reset_index()
summary_count = summary_by_anomaly\
.hvplot.barh(x = 'Summary',
            y = 'Formatted Date', 
            by = 'Wind speed emission',
            groupby = 'Year',
            grid = True, 
            height = 800,
            width = 600)
summary_count
# Out:
# :DynamicMap   [Year]
#    :Bars   [Summary,Wind speed emission]   (Formatted Date)

# %% [markdown]
# Видим что в 16м году было меньше всего дней с аномальной скоростью ветра. В основном, аномальная скорость ветра выпадает на дни с преимущественной и частичной облачностью и пасмурной погодой. В туманную погоду аномалий по ветру не наблюдается, также в ясную погоду видим в 14м и 15м году видим наличие дней с аномально высокой скоростью ветра, но в основном, в ясную погоду не наблюдается аномально высокая скорость ветра.
# Также стоит отметить, что аномальная скорость ветра подразумевает именно аномально высокую скорость ветра, потому что минимальная скорость ветра (стремящаяся к 0 км/ч) встречается достаточно часто и не может считаться выбросом.
# Аналогично с предыдущим случаем, так как в общем плане дней с облачностью больше относительно всех остальных дней, то вероятность выпадения дней с аномально высокой скоростью ветра больше в такие дни, поэтому в целом зависимости погодных условий от скорости ветра не наблюдается.

# %% [markdown]
# #### Температура по сезонам

# %%
#Temperature by Season plot
max_by_season = df_resample_date.groupby(['Year','Season'])['Temperature (C)'].max().reset_index()
min_by_season = df_resample_date.groupby(['Year','Season'])['Temperature (C)'].min().reset_index()

max_temperature_by_season = max_by_season\
.hvplot.bar(x = 'Season',
            y = 'Temperature (C)', 
            groupby = 'Year',
            grid = True, 
            width = 600)

min_temperature_by_season = min_by_season\
.hvplot.bar(x = 'Season',
            y = 'Temperature (C)', 
            groupby = 'Year',
            grid = True, 
            width = 600)
max_temperature_by_season*min_temperature_by_season
# Out:
# :DynamicMap   [Year]
#    :Overlay
#       .Bars.I  :Bars   [Season]   (Temperature (C))
#       .Bars.II :Bars   [Season]   (Temperature (C))

# %%
df_temperature = df_resample_date.groupby(['Year', 'Season'])['Temperature (C)'].agg({
    ('min_temperature', 'min'),
    ('max_temperature', 'max')
}).reset_index()
df_temperature
# Out:
#     Year  Season  max_temperature  min_temperature
# 0   2006  Autumn        23.385185        -1.259028
# 1   2006  Spring        23.341204        -2.540046
# 2   2006  Summer        27.450000        11.251157
# 3   2006  Winter         9.613194       -11.469444
# 4   2007  Autumn        21.038889        -1.620833
# 5   2007  Spring        22.881944         4.428472
# 6   2007  Summer        30.814352        16.886574
# 7   2007  Winter         9.381713        -6.675694
# 8   2008  Autumn        28.246759         0.135880
# 9   2008  Spring        25.001389         2.481944
# 10  2008  Summer        30.748380        14.893519
# 11  2008  Winter        11.490278        -8.265741
# 12  2009  Autumn        25.056481         2.031019
# 13  2009  Spring        23.696991         1.659259
# 14  2009  Summer        28.364583        13.180556
# 15  2009  Winter        12.118750       -10.305556
# 16  2010  Autumn        19.740509         1.757870
# 17  2010  Spring        21.475926        -1.755787
# 18  2010  Summer        28.293056        12.728935
# 19  2010  Winter        11.426852        -9.506250
# 20  2011  Autumn        25.400694        -2.543981
# 21  2011  Spring        22.500694        -2.484028
# 22  2011  Summer        28.893056        14.022222
# 23  2011  Winter         8.937269        -6.387269
# 24  2012  Autumn        24.006944         2.649769
# 25  2012  Spring        22.742824        -1.425000
# 26  2012  Summer        29.960417        15.849306
# 27  2012  Winter         7.272917       -15.958796
# 28  2013  Autumn        19.522454         0.548611
# 29  2013  Spring        24.130556        -2.426852
# 30  2013  Summer        28.995833        12.959259
# 31  2013  Winter         9.283796        -5.103935
# 32  2014  Autumn        21.294213         1.724074
# 33  2014  Spring        22.287963         5.676389
# 34  2014  Summer        26.596296        14.526389
# 35  2014  Winter         9.999537        -9.795139
# 36  2015  Autumn        26.493981         1.241204
# 37  2015  Spring        22.451620         3.043981
# 38  2015  Summer        29.292593        13.954167
# 39  2015  Winter         9.196528        -6.960185
# 40  2016  Autumn        23.816898         2.972917
# 41  2016  Spring        22.891667         2.345602
# 42  2016  Summer        28.371296        14.824074
# 43  2016  Winter        10.314583        -7.556019

# %% [markdown]
# На графике и из таблиц можно увидеть максимальные и минимальные температуры по сезонам в разные годы. В целом, средняя максимальная температура летом выше, средняя минимальная температура зимой ниже, что соответствует ожидаемым климатичеким условиям. Так самая минимальная температура наблюдалась зимой 2012го года, тогда она опустилась почти до -16ти градусов, самая высокая температура наблюдалась летом 2007го года когда она поднялась почти до 31 градуса
